# %% [markdown]
# 다음 크롤링_BeautifulSoup
# - 실시간 검색어 데이터 수집하기

# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime

url = "http://www.daum.net/"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
rank = 1

results = soup.findAll('a','link_favorsch')

search_rank_file = open("rankresult.txt","a")

print(datetime.today().strftime("%Y년 %m월 %d일의 실시간 검색어 순위입니다.\n"))

for result in results:
    search_rank_file.write(str(rank)+"위:"+result.get_text()+"\n")
    print(rank,"위 : ",result.get_text(),"\n")
    rank += 1
# Out:
# 2021년 03월 02일의 실시간 검색어 순위입니다.
#
# 1 위 :  코로나19 발생현황
#
# 2 위 :  슈가 2억뷰
#
# 3 위 :  석유난로
#
# 4 위 :  오승윤 미복귀전역
#
# 5 위 :  타일전문점
#
# 6 위 :  사회적 거리두기
#
# 7 위 :  MC몽 해명
#
# 8 위 :  대형텐트
#
# 9 위 :  아이유 티저
#
# 10 위 :  18k귀걸이
#
# 11 위 :  최예빈 반박
#
# 12 위 :  박정현 전속계약
#
# 13 위 :  염화칼슘
#
# 14 위 :  수지 화보
#
# 15 위 :  미니세탁기

# %%
import requests

print(requests)
# Out:
# <module 'requests' from '/usr/local/lib/python3.7/dist-packages/requests/__init__.py'>

# %% [markdown]
# #### 크롤링을 위한 블록키드 사용법
#
# 1. requests 모듈에서
# 2. get 함수를 꺼내 (get 함수 : 자... 여기 응답값>> return 응답값)
# 3. 요청을 보내줘

# %%
print(requests.get)
# Out:
# <function get at 0x7f280912acb0>

# %% [markdown]
# #### 요청하고 응답받기
#
# 1. put
# 2. get 요청을 보내는 기능
# 3. post
# 4. delete
#
# 요청(client)하면 응답한다(server)
#
# - requests 구조 확인
#
# requests.get(url, params = None, **kwargs)
#
# Return: request.Response
#
# 1) url : url for the new request object (서버의 주소)
#
# 2) params : 재료 (찾고자 하는 내용이 있는 블록)
#
# requsts.get(url)
#
# return : requests.response
#
# 마을조립키드.집 조립기계(빨간블록)
#
# return: 집

# %%
requests.get(url)
# Out:
# <Response [200]>

# %%
url = "http://www.daum.net"
requests.get(url)
# Out:
# <Response [200]>

# %%
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="ko" class="">
# <head>
# <meta charset="utf-8"/>
# <title>Daum</title>
# <meta property="og:url" content="https://www.daum.net/">
# <meta property="og:type" content="website">
# <meta property="og:title" content="Daum">
# <meta property="og:image" content="//i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001">
# <meta property="og:description" content="나의 관심 콘텐츠를 가장 즐겁게 볼 수 있는 Daum">
# <meta name="msapplication-task" content="name=Daum;action-uri=https://www.daum.net/;icon-uri=/favicon.ico">
# <meta name="msapplication-task" content="name=미디어다음;action-uri=https://news.daum.net/;icon-uri=/media_favicon.ico">
# <meta name="msapplication-task" content="name=메일;action-uri=http://mail.daum.net;icon-uri=/mail_favicon.ico">
# <meta name="referrer" content="origin">
# <link rel="search" type="application/opensearchdescription+xml" href="//search.daum.net/OpenSearch.xml" title="다음">
# ...

# %%
#print(response.url)

#print(response.content)

#print(response.encoding)

#print(response.headers)

#print(response.json)

#print(response.links)

#print(response.ok)

#print(response.status_code)

# %%
print(response.url)
# Out:
# https://www.daum.net/

# %%
print(response.content)
# Out:
# b'<!DOCTYPE html>\n<html lang="ko" class="">\n<head>\n<meta charset="utf-8"/>\n<title>Daum</title>\n<meta property="og:url" content="https://www.daum.net/">\n<meta property="og:type" content="website">\n<meta property="og:title" content="Daum">\n<meta property="og:image" content="//i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001">\n<meta property="og:description" content="\xeb\x82\x98\xec\x9d\x98 \xea\xb4\x80\xec\x8b\xac \xec\xbd\x98\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xea\xb0\x80\xec\x9e\xa5 \xec\xa6\x90\xea\xb2\x81\xea\xb2\x8c \xeb\xb3\xbc \xec\x88\x98 \xec\x9e\x88\xeb\x8a\x94 Daum">\n<meta name="msapplication-task" content="name=Daum;action-uri=https://www.daum.net/;icon-uri=/favicon.ico">\n<meta name="msapplication-task" content="name=\xeb\xaf\xb8\xeb\x94\x94\xec\x96\xb4\xeb\x8b\xa4\xec\x9d\x8c;action-uri=https://news.daum.net/;icon-uri=/media_favicon.ico">\n<meta name="msapplication-task" content="name=\xeb\xa9\x94\xec\x9d\xbc;action-uri=http://mail.daum.net;icon-ur
# ...

# %%
print(response.encoding)
# Out:
# UTF-8

# %%
print(response.headers)
# Out:
# {'Date': 'Tue, 02 Mar 2021 06:46:29 GMT', 'X-Frame-Options': 'SAMEORIGIN', 'X-UA-Compatible': 'IE=10', 'Expires': 'Sat, 01, Jan 1970 22:00:00 GMT', 'Pragma': 'no-cache', 'Cache-Control': 'no-cache, no-store, must-revalidate', 'P3P': 'CP="ALL DSP COR MON LAW IVDi HIS IVAi DELi SAMi OUR LEG PHY UNI ONL DEM STA INT NAV PUR FIN OTC GOV"', 'Content-Type': 'text/html;charset=UTF-8', 'Content-Language': 'en-US', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'X-UA-Device-Type': 'pc', 'Content-Length': '48555', 'Connection': 'close'}

# %%
print(response.json)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
print(response.links)
# Out:
# {}

# %%
print(response.ok)
# Out:
# True

# %%
print(response.status_code)
# Out:
# 200

# %%
from bs4 import BeautifulSoup

# %%
print(BeautifulSoup(response.text, 'html.parser'))
# Out:
# <!DOCTYPE html>
#
# <html class="" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <title>Daum</title>
# <meta content="https://www.daum.net/" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="Daum" property="og:title"/>
# <meta content="//i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001" property="og:image"/>
# <meta content="나의 관심 콘텐츠를 가장 즐겁게 볼 수 있는 Daum" property="og:description"/>
# <meta content="name=Daum;action-uri=https://www.daum.net/;icon-uri=/favicon.ico" name="msapplication-task"/>
# <meta content="name=미디어다음;action-uri=https://news.daum.net/;icon-uri=/media_favicon.ico" name="msapplication-task"/>
# <meta content="name=메일;action-uri=http://mail.daum.net;icon-uri=/mail_favicon.ico" name="msapplication-task"/>
# <meta content="origin" name="referrer"/>
# <link href="//search.daum.net/OpenSearch.xml" rel="search" title="다음" type="application/opensearchdescription+xml"/>
# ...

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="ko" class="">
# <head>
# <meta charset="utf-8"/>
# <title>Daum</title>
# <meta property="og:url" content="https://www.daum.net/">
# <meta property="og:type" content="website">
# <meta property="og:title" content="Daum">
# <meta property="og:image" content="//i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001">
# <meta property="og:description" content="나의 관심 콘텐츠를 가장 즐겁게 볼 수 있는 Daum">
# <meta name="msapplication-task" content="name=Daum;action-uri=https://www.daum.net/;icon-uri=/favicon.ico">
# <meta name="msapplication-task" content="name=미디어다음;action-uri=https://news.daum.net/;icon-uri=/media_favicon.ico">
# <meta name="msapplication-task" content="name=메일;action-uri=http://mail.daum.net;icon-uri=/mail_favicon.ico">
# <meta name="referrer" content="origin">
# <link rel="search" type="application/opensearchdescription+xml" href="//search.daum.net/OpenSearch.xml" title="다음">
# ...

# %% [markdown]
# - 똑같은 결과물처럼 보임. But 실제로는 다름

# %%
print(type(response.text)) # 문자열
# Out:
# <class 'str'>

# %%
print(type(BeautifulSoup(response.text, 'html.parser'))) #문자열을 bs라는 통에 넣은 상태임
# 대상이 되는 텍스트(response.text)를 html을 parsing(분리)하여 담아라
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
 soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.title)
# Out:
# <title>Daum</title>

# %%
print(response.text[:500]) # text에서 500개까지만 추출(slicing)
# Out:
# <!DOCTYPE html>
# <html lang="ko" class="">
# <head>
# <meta charset="utf-8"/>
# <title>Daum</title>
# <meta property="og:url" content="https://www.daum.net/">
# <meta property="og:type" content="website">
# <meta property="og:title" content="Daum">
# <meta property="og:image" content="//i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001">
# <meta property="og:description" content="나의 관심 콘텐츠를 가장 즐겁게 볼 수 있는 Daum">
# <meta name="msapplication-task" content="name=Daum;action-uri=https://www.daum.net/;icon-uri

# %%
print(soup.title.string)
# Out:
# Daum

# %%
print(soup.span)
# Out:
# <span class="ico_vert inner_shortcut">주요 서비스 바로가기</span>

# %%
print(soup.findAll('span'))
# Out:
# [<span class="ico_vert inner_shortcut">주요 서비스 바로가기</span>, <span class="ico_vert inner_shortcut">오늘의 정보 바로가기</span>, <span class="ico_vert inner_shortcut">미디어 바로가기</span>, <span class="ico_vert inner_shortcut">실시간 이슈 바로가기</span>, <span class="ico_vert inner_shortcut">멀티미디어 바로가기</span>, <span class="ico_vert inner_shortcut">블로그 정보 바로가기</span>, <span class="ico_vert inner_shortcut">유익한 정보 바로가기</span>, <span class="ico_vert inner_shortcut">쇼핑 바로가기</span>, <span class="ico_vert inner_shortcut">오늘의 포토&amp;영상 바로가기</span>, <span class="ico_vert inner_shortcut">웹 접근성 안내</span>, <span class="ico_vert inner_shortcut">자동실행 광고 설정</span>, <span class="ir_wa">한글입력기</span>, <span class="ir_wa">검색</span>, <span class="ir_wa">&lt;이전</span>, <span class="ir_wa">&gt;다음</span>, <span class="ir_wa">카페</span>, <span class="ir_wa">메일</span>, <span class="ir_wa">뉴스</span>, <span class="ir_wa">지도</span>, <span class="ir_wa">증권</span>, <span class="ir_wa">쇼핑</span>, <span class="ir_wa">카카오TV</span>, <span cla
# ...

# %%
file = open("daum.html","w", encoding = 'utf-8') #file을 daum.html로 설정 
file.write(response.text)
file.close()

# %%
# html 문서에서 모든 a태그를 가져오는 코드

print(soup.findAll("a"))
# Out:
# [<a class="shortcut_g" href="#mainServiceTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">주요 서비스 바로가기</span>
# </a>, <a class="shortcut_g" href="#todayInfoTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">오늘의 정보 바로가기</span>
# </a>, <a class="shortcut_g" href="#mediaTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">미디어 바로가기</span>
# </a>, <a class="shortcut_g" href="#liveIssueTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">실시간 이슈 바로가기</span>
# </a>, <a class="shortcut_g" href="#multiMediaTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">멀티미디어 바로가기</span>
# </a>, <a class="shortcut_g" href="#blogTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">블로그 정보 바로가기</span>
# </a>, <a class="shortcut_g" href="#storyTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">유익한 정보 바로가기</span>
# ...

# %%
print(soup.findAll("a", "link_favorsch")) #a tag 중 공통으로 가지고 있는 link_favorsch 출력
# Out:
# [<a class="link_favorsch @6" href="https://search.daum.net/search?w=tot&amp;q=%EC%BD%94%EB%A1%9C%EB%82%9819+%EB%B0%9C%EC%83%9D%ED%98%84%ED%99%A9&amp;DA=NPI">코로나19 발생현황</a>, <a class="link_favorsch @7" href="https://search.daum.net/search?w=tot&amp;q=%EC%8A%88%EA%B0%80+2%EC%96%B5%EB%B7%B0&amp;DA=NPI&amp;rtmaxcoll=NNS">슈가 2억뷰</a>, <a class="link_favorsch @8" href="https://search.daum.net/search?w=tot&amp;q=%EC%84%9D%EC%9C%A0%EB%82%9C%EB%A1%9C&amp;DA=NPT">석유난로</a>, <a class="link_favorsch @9" href="https://search.daum.net/search?w=tot&amp;q=%EC%98%A4%EC%8A%B9%EC%9C%A4+%EB%AF%B8%EB%B3%B5%EA%B7%80%EC%A0%84%EC%97%AD&amp;DA=NPI&amp;rtmaxcoll=NNS">오승윤 미복귀전역</a>, <a class="link_favorsch @10" href="https://search.daum.net/search?w=tot&amp;q=%ED%83%80%EC%9D%BC&amp;DA=NPT">타일전문점</a>, <a class="link_favorsch @6" href="https://search.daum.net/search?w=tot&amp;q=%EC%82%AC%ED%9A%8C%EC%A0%81+%EA%B1%B0%EB%A6%AC%EB%91%90%EA%B8%B0&amp;DA=NPI">사회적 거리두기</a>, <a class="link_favorsch @7" href="https://searc
# ...

# %%
results = soup.findAll("a", "link_favorsch")

for result in results: 
    print(result,"\n") #"\" 줄 바꿈
# Out:
# <a class="link_favorsch @6" href="https://search.daum.net/search?w=tot&amp;q=%EC%BD%94%EB%A1%9C%EB%82%9819+%EB%B0%9C%EC%83%9D%ED%98%84%ED%99%A9&amp;DA=NPI">코로나19 발생현황</a>
#
# <a class="link_favorsch @7" href="https://search.daum.net/search?w=tot&amp;q=%EC%8A%88%EA%B0%80+2%EC%96%B5%EB%B7%B0&amp;DA=NPI&amp;rtmaxcoll=NNS">슈가 2억뷰</a>
#
# <a class="link_favorsch @8" href="https://search.daum.net/search?w=tot&amp;q=%EC%84%9D%EC%9C%A0%EB%82%9C%EB%A1%9C&amp;DA=NPT">석유난로</a>
#
# <a class="link_favorsch @9" href="https://search.daum.net/search?w=tot&amp;q=%EC%98%A4%EC%8A%B9%EC%9C%A4+%EB%AF%B8%EB%B3%B5%EA%B7%80%EC%A0%84%EC%97%AD&amp;DA=NPI&amp;rtmaxcoll=NNS">오승윤 미복귀전역</a>
#
# <a class="link_favorsch @10" href="https://search.daum.net/search?w=tot&amp;q=%ED%83%80%EC%9D%BC&amp;DA=NPT">타일전문점</a>
#
# <a class="link_favorsch @6" href="https://search.daum.net/search?w=tot&amp;q=%EC%82%AC%ED%9A%8C%EC%A0%81+%EA%B1%B0%EB%A6%AC%EB%91%90%EA%B8%B0&amp;DA=NPI">사회적 거리두기</a>
#
# ...

# %%
for result in results: 
    print(result.get_text(),"\n") #"\" 줄 바꿈
# Out:
# 코로나19 발생현황
#
# 슈가 2억뷰
#
# 석유난로
#
# 오승윤 미복귀전역
#
# 타일전문점
#
# 사회적 거리두기
#
# MC몽 해명
#
# 대형텐트
#
# 아이유 티저
#
# 18k귀걸이
#
# 최예빈 반박
#
# 박정현 전속계약
#
# 염화칼슘
#
# 수지 화보
#
# 미니세탁기

# %%
rank = 1

for result in results: 
    print(rank,"위:", result.get_text(),"\n") #"\" 줄 바꿈
    rank += 1
# Out:
# 1 위: 코로나19 발생현황
#
# 2 위: 슈가 2억뷰
#
# 3 위: 석유난로
#
# 4 위: 오승윤 미복귀전역
#
# 5 위: 타일전문점
#
# 6 위: 사회적 거리두기
#
# 7 위: MC몽 해명
#
# 8 위: 대형텐트
#
# 9 위: 아이유 티저
#
# 10 위: 18k귀걸이
#
# 11 위: 최예빈 반박
#
# 12 위: 박정현 전속계약
#
# 13 위: 염화칼슘
#
# 14 위: 수지 화보
#
# 15 위: 미니세탁기

# %%
from datetime import datetime 

print(datetime.today())
# Out:
# 2021-03-02 06:48:54.221086

# %%
print(datetime.today().strftime("%Y년 %m월 %d일의 실시간 검색어 순위\n"))
# Out:
# 2021년 03월 02일의 실시간 검색어 순위

# %% [markdown]
# ### 파일로 출력하기
#
# open("rankresult.txt", 모드)
#
# - 모드
#  - r : read
#  - w:  write
#  - a : append

# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime

url = "http://www.daum.net/"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
rank = 1

results = soup.findAll('a','link_favorsch')

# 파일로 출력하기 
search_rank_file = open("rankresult.txt","w")

print(datetime.today().strftime("%Y년 %m월 %d일의 실시간 검색어 순위입니다.\n"))

for result in results:
    search_rank_file.write(str(rank)+"위:"+result.get_text()+"\n") #str(rank): rank는 숫자 변수 >> 문자 변환
    print(rank,"위 : ",result.get_text(),"\n")
    rank += 1
# Out:
# 2021년 03월 02일의 실시간 검색어 순위입니다.
#
# 1 위 :  코로나19 발생현황
#
# 2 위 :  슈가 2억뷰
#
# 3 위 :  석유난로
#
# 4 위 :  오승윤 미복귀전역
#
# 5 위 :  타일전문점
#
# 6 위 :  사회적 거리두기
#
# 7 위 :  MC몽 해명
#
# 8 위 :  대형텐트
#
# 9 위 :  아이유 티저
#
# 10 위 :  18k귀걸이
#
# 11 위 :  최예빈 반박
#
# 12 위 :  박정현 전속계약
#
# 13 위 :  염화칼슘
#
# 14 위 :  수지 화보
#
# 15 위 :  미니세탁기

# %%
# 파일 계속 업데이트("a": append)

from bs4 import BeautifulSoup
import requests
from datetime import datetime

url = "http://www.daum.net/"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
rank = 1

results = soup.findAll('a','link_favorsch')

# 파일을 지속적으로 업데이트 하기("a"" append) 
search_rank_file = open("rankresult.txt","a")

print(datetime.today().strftime("%Y년 %m월 %d일의 실시간 검색어 순위입니다.\n"))

for result in results:
    search_rank_file.write(str(rank)+"위:"+result.get_text()+"\n") #str(rank): rank는 숫자 변수 >> 문자 변환
    print(rank,"위 : ",result.get_text(),"\n")
    rank += 1
# Out:
# 2021년 03월 02일의 실시간 검색어 순위입니다.
#
# 1 위 :  코로나19 발생현황
#
# 2 위 :  슈가 2억뷰
#
# 3 위 :  석유난로
#
# 4 위 :  오승윤 미복귀전역
#
# 5 위 :  타일전문점
#
# 6 위 :  사회적 거리두기
#
# 7 위 :  MC몽 해명
#
# 8 위 :  대형텐트
#
# 9 위 :  아이유 티저
#
# 10 위 :  18k귀걸이
#
# 11 위 :  최예빈 반박
#
# 12 위 :  박정현 전속계약
#
# 13 위 :  염화칼슘
#
# 14 위 :  수지 화보
#
# 15 위 :  미니세탁기

# %% [markdown]
# - 응용해 보기 (네이버 데이터랩 크롤링하기")

# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime

# 네이버는 bot 차단, 일반 사용자(user)임을 알리는 headers 필요 
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}

url = "https://datalab.naver.com/keyword/realtimeList.naver?age=20s"
response = requests.get(url,headers=headers) # headers=headers 필요 
soup = BeautifulSoup(response.text, 'html.parser')
rank = 1
# 네이버 구조 : span - item_title 
results = soup.findAll('span','item_title')

print(response.text)

search_rank_file = open("rankresult.txt","a")

print(datetime.today().strftime("%Y년 %m월 %d일의 실시간 검색어 순위입니다.\n"))

for result in results:
    search_rank_file.write(str(rank)+"위:"+result.get_text()+"\n")
    print(rank,"위 : ",result.get_text(),"\n")
    rank += 1
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=1200">
#     <title>급상승검색어 : 네이버 데이터랩</title>
#     <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.datalab/202102250221/css/datalab.css">
#     <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.datalab/202102250221/css/graph.css">
#
#     <link rel="icon" sizes="192x192" href="https://ssl.pstatic.net/static.datalab/202102250221/img/favicon/android_legacy_xxxhpdi_192x192.png" >
#     <link rel="icon" sizes="144x144" href="https://ssl.pstatic.net/static.datalab/202102250221/img/favicon/android_legacy_xxhpdi_144x144.png" >
#     <link rel="icon" sizes="96x96" href="https://ssl.pstatic.net/static.datalab/202102250221/img/favicon/android_legacy_xhdpi_96x96.png" >
# ...

# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
url = "https://datalab.naver.com/keyword/realtimeList.naver?age=20s"
response = requests.get(url,headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
rank = 1
# span - item_title
# results = soup.findAll('span','item_title')
# print(response.text)

search_rank_file = open("rankresult.txt","a")

print(datetime.today().strftime("%Y년 %m월 %d일의 실시간 검색어 순위입니다.\n"))

for result in results:
    search_rank_file.write(str(rank)+"위:"+result.get_text()+"\n")
    print(rank,"위 : ",result.get_text(),"\n")
    rank += 1
# Out:
# 2021년 03월 02일의 실시간 검색어 순위입니다.
#
# 1 위 :  함소원 진화
#
# 2 위 :  함소원
#
# 3 위 :  찬열
#
# 4 위 :  제니 지디
#
# 5 위 :  기성용
#
# 6 위 :  오은영
#
# 7 위 :  제니
#
# 8 위 :  진화
#
# 9 위 :  이주연
#
# 10 위 :  지디
#
# 11 위 :  지드래곤
#
# 12 위 :  임영웅 대학교
#
# 13 위 :  서현민
#
# 14 위 :  김현우
#
# 15 위 :  박찬열
#
# 16 위 :  변정하
#
# 17 위 :  이지혜
#
# 18 위 :  범죄도시
#
# 19 위 :  파오차이
#
# 20 위 :  프렌즈 김현우
