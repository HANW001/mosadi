# %% [markdown]
# 머신러닝이란 광학 문자판독기(OCR), 스팸필터 등 스스로 학습되어 있다. 이후 추천과 음성 검색으로 발전했다. 기계가 배운다.

# %% [markdown]
# 지도 학습과 비지도 학습, 온라인 학습과 배치학습, 사례기반 학습과 모델기반 학습이 있다.

# %% [markdown]
# ## 머신러닝이란?

# %% [markdown]
# 명시적인 프로그래밍 없이 컴퓨터가 학습하는 능력을 갖추게 하는 연구분야

# %% [markdown]
# 어떤 작업 T 에 대한 컴퓨터 프로그램의 성능을 P로 측정 했을 때 경험 E로 인해 성능이 향상됐다면 이 컴퓨터 프로그램은 작업 T와 성능 측정 P 에 대해 경험 E로 학습 한 것이다.

# %% [markdown]
# 스팸 필터는 스팸 메일과 일반 메일의 샘플을 이요해 스팸 메일 구분법을 배울 수있는 머신러닝 프로그램이다. 샘플을 '**훈련 세트(training set)**' 라고 하고 각 훈련 데이터를 '**훈련 사례(training instance)**'혹은 샘플 이라고 한다. 작업 T는 새로운 메일이 스팸인지 구분 하는 것이고, 경험 E는 훈련 데이터(training data)이며 성능 측정 P는 직접 정의 한다. 정확히 분류된 메일의 비율을 P로 사용 할 수있다. 이 성능 측정을 '**정확도(accuracy)**' 라고 한다.

# %% [markdown]
# ## 왜 머신러닝을 사용 하는가?

# %% [markdown]
# ![프로그램 기법 전통.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 유지 보수가 많이 어렵다

# %% [markdown]
# ![전통적인.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 머신러닝은 스팸이 자주 나타나는 패턴을 감지하여 스팸 메일을 판단하는데 좋은 기준인지 자동으로 학습한다.

# %% [markdown]
# ![머신러인 접근방법.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 머신러닝 기반의 스팸 필터는 사용자가 별도로 작업을 하지 않아도 자동으로 이 단어를 스팸으로 분류한다.

# %% [markdown]
# ![자동으로 변화.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 스팸 필터가 충부한 스팸 메일로 훈련되었다면 스팸을 예측하는 데 가장 좋은 단어 및 단어의조합을 생각해서 확인 할수 있따. 예상치 못한 연관 관계나 새로운 추세가 발견되기도 해서 해당 문제를 더 잘 이해하도록 도와준다. 대용량의 데이터를 분석하면 보이지 않던 패턴을 발견 할 수 있다. 이를 데이터 마이닝 이라고 한다.

# %% [markdown]
# ![마이닝.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 머신러닝 시스템의 종류

# %% [markdown]
# ![시스템 종류.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### 지도학습과 비지도 학습

# %% [markdown]
# 지도:[이미지, 이미지 클래스]
# 비지도: [ 이미지]
# 정답이 잇다 없다 차이

# %% [markdown]
# #### 지도학습

# %% [markdown]
# 알고리즘에 주입하는 훈련 데이털에 레이블(label)이라는 원하는 답이 포함된다.

# %% [markdown]
# ![지도학습.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 분류(classification)가 전형적인 지도 학습 작업이다. 스팸필터가 좋은 예다.

# %% [markdown]
# 예측 변수(predictor varable)라 부르는 특성(feature)(주행거리, 연식, 브랜드 등)을 사용해 중고차 가격 같은 타깃(target)수치를 예측 하는 것이다. 이런 작업을 회귀(regression)라고 부른다.

# %% [markdown]
# 속성(attribute)은 데이터 타입(주행거리..)을 말한다. 특성은 문맥에 따라 여러 의미를 갖지만 일반적으로 속성과 값이 합쳐진 것을 의미한다.( 주행거리 = 15,000) 하지만 속성과 특성을 크게 구분하지 않는다.

# %% [markdown]
# ![회귀문제.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 일부 분류 알고리즘을 회귀에서 사용할 수 있다. 로지스틱 회귀는 클래스에 속할 확률을 출력한다.(스팸일 가능성 20%)

# %% [markdown]
# ![지도학습알로기름.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### 비지도 학습

# %% [markdown]
# 훈련 데이터에 레이블이 없다. 아무런 도움없이 학습 해야한다.

# %% [markdown]
# ![비지도학습세트.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![비지도알고리즘.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 비슷한 방문자들을 그룹으로 묶기 위해 군집 알고리즘을 사용하려 한다. 하지만 어떤 그룹에 속하는지 알려줄 데이터 포인트가 없다. 그래서 알고리즘이 스스로 연결고리를 찾는다. 계층 군집 알고리즘을 사용하면 각 그룹을 더 작은 그룹으로 세분화 할 수 있다.

# %% [markdown]
# ![군집.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 시각화 알고리즘은 레이블이 없는 대규모의 고차원 데이터를 넣으면 도식화가 가능한 2D나 3D표현을 만들어준다. 가능한 한 구조를 그대로 유지하려 하므로 데이터가 어떻게 조직되어 있는지 이해할 수 있고 예상하지 못한 패턴을 발견할 수 있다.

# %% [markdown]
# 너무 많은 정보를 잃지 않으면서 데이터를 간소화 하는 차원 축소가 있다. 상관관계가 있는 여러 특성을 하나로 합치는 것이다. 예를 들어 차의 주행거리는 연식과 강하게 연관되어 있으므로 차원축소알고르즘으로 두 특성을 차의 마모 정도를 나타내는 하나의 특성으로 합칠 수 있다. 이를 특성 추출 이라고 한다.

# %% [markdown]
# ![군집 시각화.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 이상치 탐지는 부정 거래를 막기위해 이상한 신용카드 거래를 감지하고, 제조 결함을 잡아내고, 학습 알고리즘에 주입하기 전에 데이터셋에서 이상한 값을 자동으로 제거한다.

# %% [markdown]
# 시스템은 훈련하는 동안 대부분 정상 샘플을 만나 이를 인식하도록 훈련된다. 그다음 새로운 샘플을 보고 정상 데이터인지 혹은 이상치 인지 판단한다.

# %% [markdown]
# ![이상치탐지.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 특이치 탐지와 매우 비슷하다. 훈련 세트에 있는 모든 샘플과 달라보이는 새로운 샘플을 탐지 하는게 목적이다. 알고리즘으로 감지하고 싶은 모든 샘플을 제거한 매우 깨끗한 훈련 세트가 필요하다.

# %% [markdown]
# 대량의 데이터에서 특성간의 흥미로운 관계를 찾는 연관 규칙 학습이 있다.

# %% [markdown]
# #### 준지도 학습

# %% [markdown]
# 레이블이 없는 샘플이 많고 레이블된 샘플은 적은 경우가 많다. 어떤 알고리즘은 일부만 레이블이 있는 데이터를 다룰 수 있다. 이를 준지도 학습이라 한다.

# %% [markdown]
# ![준지도학습.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 대부분의 준지도 학습 알고리즘은 지도 학습과 비지도 학습의 조합으로 이루어져 있다. 심층 신뢰 신경망(DBN)은 여러 겹으로 쌓은 제한된 볼츠만 머신(RBM)이라 불리는 비지도 학습에 기초한다. RBM이 비지도 학습 방식으로 순차적으로 훈련된 다음 전체 시스템이 지도 학습 방식으로 세밀하게 조정된다.

# %% [markdown]
# #### 강화학습

# %% [markdown]
# 시스템을 에이전트라 부르며 환경을 관찰해서 행동을 실행하고 그 결과로 보상을 받는다. 시간이 지나면서 가장 큰 보상을 얻기 위해 정책이라고 부르는 최상의 전략을 스스로 학습한다.

# %% [markdown]
# ### 배치학습과 온라인 학습

# %% [markdown]
# 머신러닝 시스템을 분류하는 데 사용하는 다른 기준은 입력 데이터의 스트림부터 점진적으로 학습할 수 있는지 여부다.

# %% [markdown]
# #### 배치학습

# %% [markdown]
# 배치학습은 시스템이 점진적으로 학습할수 없다. 가용한 데이터를 모두 사용해 훈련시켜야 한다. 시간과 자원을 많이 소모하므로 오프라인에서 수행된다. 먼저 시스템을 훈련시키고 제품 시스템에 적용하면 더이상의 학습없이 실행된다.

# %% [markdown]
# 새로운 데이터에 대해 학습하려면 전체 데이터를 사용하여 새로운 버전을 처음부터 다시 훈련해야한다. 이전 시스템을 중지시키고 새 시스템으로 교체한다.

# %% [markdown]
# #### 온라인 학습

# %% [markdown]
# 순차적으로 한개 씩 또는 미니 배치라 부르는 작은 묶음 단위로 주입하여 시스템을 훈련시킨다.

# %% [markdown]
# ![온라인학습.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 연속적으로 데이터를 받고 빠른 변화에 스스로 적응해야 하는 시스템에 적합하다.

# %% [markdown]
# ![온라인학습 대량처리.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 중요한 파라미터 하나는 변화하는 데이터에 얼마나 빠르게 적응할것인가다. 이를 학습률이라 한다. 학습률이 높으면 시스템이 데이터에 빠르게 적응하지만 예전 데이터를 금장 잊어 버린다. 반대로 낮으면 시스템 관성이 커져서 더 느리게 학습된다. 하지만 잡음이나 대표성이 없는 데이터 포인트에 덜 민감해진다.

# %% [markdown]
# ### 사례기반 학습과 모델 기반 학습

# %% [markdown]
# 어떻게 일반화 되는가에 따라 분류할수있다.

# %% [markdown]
# #### 사례기반 학습

# %% [markdown]
# 스팸 메일과 동일한 메일을 스팸이라고 지정하는 대신 스팸 메일과 매우 유사한 메일을 구분하도록 스팸 필터를 프로그래밍 할수있다. 두 메일 사이의 유사도를 측정해야한다.

# %% [markdown]
# 사례 기반 학습이라고 한다. 시스템이 훈련 샘플을 기억함으로써 학습한다.

# %% [markdown]
# ![사례기반학습.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### 모델기반 학습

# %% [markdown]
# 샘플들의 모델을 만들어 예측에 사용하는것을 모델 기반 학습이라 한다.

# %% [markdown]
# ![모델기반학습.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 모델을 사용하기 전에 a0과 a1을 정의 해야 한다. 모델이 얼마나 좋은지 측정하는 효용함수(적합도함수)를 정의하거나 얼마나 나쁜지 측정하는 비용함수를 정의할수있다. 이거리를 최소화 하는것이 목표다. 알고리즘에 훈련 데이터를 공급하면 데이터에 가장 잘 맞는 선형 모델의 파라미터를 찾는다. 이를 모델을 훈련시킨다 한다.

# %% [markdown]
# 데이터를 분석한다. 모델을 선택한다. 훈련데이터로 모델을 훈련시킨다. (비용함수를 최소하 하는 모델 파라미터를 찾는다.) 새로운 데이터 모델을 적용해 예측하고(추론) 이 모델이 잘 일반화 되길 기대한다.

# %% [markdown]
# ### 머신러닝의 주요 도전 과제

# %% [markdown]
# 데이터 훈련에 문제가 되는 것은 나쁜알고리즘과 나쁜 데이터이다.

# %% [markdown]
# #### 충분하지 않은 양의 훈련 데이터

# %% [markdown]
# 대부분의 머신러닝 알고리즘이 잘 작동하려면 데이터가 많아야 한다.

# %% [markdown]
# ![터데이.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### 대표성 없는 훈련 데이터
